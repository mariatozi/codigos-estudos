# %% [markdown]
# <a href="https://colab.research.google.com/github/mariatozi/projetospessoais/blob/main/Guemba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
notas = pd.read_excel('AcompX.xlsx')
notas
# Out:
#           Rótulos de Linha  Contagem de Problema
# 0            Chamada longa                     1
# 1                 Contagem                     1
# 2                  Default                     1
# 3                  Desloga                     3
# 4      Exibição Seguradora                     1
# 5                 Lentidão                     4
# 6                  Ligação                     1
# 7           Lista Suspensa                     1
# 8                    Pausa                    14
# 9   Pesquisa de Satisfação                     4
# 10            Ramal Manual                     1
# 11              StartPhone                     7
# 12               Tabulador                     4
# 13               Telefonia                     1
# 14           Transf. Porto                     1
# 15              Travamento                     2
# 16                     URA                     1

# %%
notas.head()
# Out:
#       Rótulos de Linha  Contagem de Problema
# 0        Chamada longa                     1
# 1             Contagem                     1
# 2              Default                     1
# 3              Desloga                     3
# 4  Exibição Seguradora                     1

# %%
notas.shape
# Out:
# (17, 2)

# %%
notas.columns = ['Problemas', 'Relatos']
notas
# Out:
#                  Problemas  Relatos
# 0            Chamada longa        1
# 1                 Contagem        1
# 2                  Default        1
# 3                  Desloga        3
# 4      Exibição Seguradora        1
# 5                 Lentidão        4
# 6                  Ligação        1
# 7           Lista Suspensa        1
# 8                    Pausa       14
# 9   Pesquisa de Satisfação        4
# 10            Ramal Manual        1
# 11              StartPhone        7
# 12               Tabulador        4
# 13               Telefonia        1
# 14           Transf. Porto        1
# 15              Travamento        2
# 16                     URA        1

# %%
tabela_problemas = notas.groupby('Problemas').sum()
display(tabela_problemas)
# Out:
#                         Relatos
# Problemas
# Chamada longa                 1
# Contagem                      1
# Default                       1
# Desloga                       3
# Exibição Seguradora           1
# Lentidão                      4
# Ligação                       1
# Lista Suspensa                1
# Pausa                        14
# Pesquisa de Satisfação        4
# Ramal Manual                  1
# StartPhone                    7
# Tabulador                     4
# Telefonia                     1
# Transf. Porto                 1
# Travamento                    2
# URA                           1

# %%
grafico = px.bar(tabela_problemas, x=tabela_problemas.index, y='Relatos')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
